# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import networkx as nx
from bokeh.plotting import figure
from bokeh.layouts import gridplot,widgetbox,column

from bokeh.io import show, output_file
from bokeh.models import Plot, GraphRenderer, Range1d, MultiLine, Circle, HoverTool, TapTool, BoxSelectTool, LassoSelectTool, LabelSet, ColumnDataSource, Arrow, OpenHead, Jitter, CustomJS
from bokeh.models.graphs import from_networkx, NodesAndLinkedEdges, EdgesAndLinkedNodes, NodesOnly, StaticLayoutProvider
from bokeh.palettes import Spectral4, Blues8, Reds8
from bokeh.models.widgets import Div,RangeSlider

# %%
df_node = pd.read_csv("data/sheep_age.csv", header=0, index_col=0)
df_edge = pd.read_csv("data/sheep_edges.csv", header=0, index_col =None)

# %%
df_edge = pd.merge(df_edge, df_node.reset_index(), left_on='source', right_on='id').rename({'age':'source_age'}, axis='columns')
df_edge = pd.merge(df_edge, df_node.reset_index(), left_on='target', right_on='id').rename({'age':'target_age'}, axis='columns')
df_edge['older_win'] = df_edge['source_age'] > df_edge['target_age']
df_edge['older_lose'] = df_edge['source_age'] < df_edge['target_age']

# %%
# augmented features for each sheep node
df_node['win'] = df_edge.groupby(['source']).count()['target']
df_node['weighted_win'] = df_edge.groupby(['source']).agg({"weight": "sum"})
df_node['lose'] = df_edge.groupby(['target']).count()['source']
df_node['weighted_lose'] = df_edge.groupby(['target']).agg({"weight": "sum"})
df_node.fillna(0, inplace=True)
df_node['win'] = df_node['win'].astype(int)
df_node['lose'] = df_node['lose'].astype(int)

df_node['score'] = df_node['win'] - df_node['lose']
df_node['weighted_score'] = df_node['weighted_win'] - df_node['weighted_lose']
df_node['total'] = df_node['win'] + df_node['lose']
df_node['win_older'] = df_edge[df_edge['older_win']].groupby('source').count()['older_win']
df_node['lose_older'] = df_edge[df_edge['older_lose']].groupby('target').count()['older_lose']
df_node.fillna(0, inplace=True)
df_node.reset_index(inplace=True)
df_node['label'] = df_node.apply(lambda row: "s{}-{}/{}".format(int(row['id']), int(row['win']),int(row['lose'])), axis=1)
df_node.set_index(['id'], inplace=True)
df_node['index'] = df_node.index

# %%
df_node.sort_values(['age'])
# Out:
#     age  win  weighted_win  lose  weighted_lose  score  weighted_score  total  \
# id
# 14    1   11          31.0    11           28.0      0             3.0     22
# 22    1   16          65.0     3           10.0     13            55.0     19
# 18    1   10          35.0    13           25.0     -3            10.0     23
# 24    1    6          25.0    11           38.0     -5           -13.0     17
# 19    1    7          16.0    13           50.0     -6           -34.0     20
# 6     3    0           0.0    19           62.0    -19           -62.0     19
# 26    3    3           8.0    19           54.0    -16           -46.0     22
# 21    3    1          10.0    21           47.0    -20           -37.0     22
# 20    3    2           4.0    17           45.0    -15           -41.0     19
# 8     4   14          56.0     4           18.0     10            38.0     18
# 3     4   18          63.0     8           36.0     10            27.0     26
# 12    4    7          13.0     4            4.0      3             9.0     11
# 27    4    1           1.0    11           16.0    -10           -15.0     12
# 17    4    7           8.0    10           18.0     -3           -10.0     17
# 7     5   16          43.0     1            1.0     15            42.0     17
# 11    6   10          14.0     6            8.0      4             6.0     16
# 9     7   16          52.0     6           18.0     10            34.0     22
# 4     7   17          25.0     9           15.0      8            10.0     26
# 23    7    9          17.0    12           56.0     -3           -39.0     21
# 1     8    5           5.0     0            0.0      5             5.0      5
# 5     8    2           2.0     5            5.0     -3            -3.0      7
# 2     8   14          35.0     5            9.0      9            26.0     19
# 15    9   11          24.0     9           22.0      2             2.0     20
# 13    9   14          30.0     7           19.0      7            11.0     21
# 10    9    3           3.0     1            1.0      2             2.0      4
# 25    9    6          25.0    12           22.0     -6             3.0     18
# 16    9    9          16.0    10           19.0     -1            -3.0     19
# 28    9   15          32.0     3           12.0     12            20.0     18
#
#     win_older  lose_older      label  index
# id
# 14        0.0         0.0  s14-11/11     14
# 22        0.0         0.0   s22-16/3     22
# 18        0.0         0.0  s18-10/13     18
# 24        0.0         0.0   s24-6/11     24
# 19        0.0         0.0   s19-7/13     19
# 6         0.0         5.0    s6-0/19      6
# 26        0.0         5.0   s26-3/19     26
# 21        0.0         4.0   s21-1/21     21
# 20        0.0         4.0   s20-2/17     20
# 8         6.0         1.0    s8-14/4      8
# 3         8.0         1.0    s3-18/8      3
# 12        3.0         0.0    s12-7/4     12
# 27        1.0         3.0   s27-1/11     27
# 17        4.0         1.0   s17-7/10     17
# 7         9.0         0.0    s7-16/1      7
# 11        6.0         2.0   s11-10/6     11
# 9         9.0         5.0    s9-16/6      9
# 4        11.0         6.0    s4-17/9      4
# 23        8.0         6.0   s23-9/12     23
# 1         3.0         0.0     s1-5/0      1
# 5         1.0         4.0     s5-2/5      5
# 2        11.0         3.0    s2-14/5      2
# 15       11.0         7.0   s15-11/9     15
# 13       12.0         7.0   s13-14/7     13
# 10        2.0         1.0    s10-3/1     10
# 25        6.0        10.0   s25-6/12     25
# 16        8.0         8.0   s16-9/10     16
# 28       13.0         3.0   s28-15/3     28

# %%
def generate_network(df_n, df_e):
    g = nx.DiGraph()

    for i,n in df_n.iterrows():
        g.add_node(i,**n.to_dict())

    for i,e in df_e.iterrows():
        g.add_edge(e['source'], e['target'], **e.to_dict())
        #weights.append(w['weight'])
        #G.add_edge(int(e[0]),int(e[1]))
    return g

def generate_network1(df_n, df_e):
    g = nx.from_pandas_edgelist(df_e, 'source', 'target', 'weight')
    for i in sorted(G.nodes()):
        for attr in df_n.columns:
            g.node[i][attr] = df_n[attr][i]
    return g

# %%
df_source = df_node.sort_values(['age'])
G = generate_network(df_source, df_edge)
G1 = generate_network(df_source, df_edge)


max_score, min_score = df_source['score'].max(), df_source['score'].min()
df_source['size'] = df_source['total'] * 2
df_source['color_idx'] = df_source.apply(lambda row: 8-int(8*(row['score'])/max_score) if row['score']>0 else 7-int(8*(row['score'])/min_score), axis=1)
df_source['fill_color'] = df_source.apply(lambda row: Reds8[row['color_idx']] if row['score']>=0 else Blues8[row['color_idx']], axis=1)

# %%
pos = nx.circular_layout(G, scale=1, center=(0,0))
x,y = zip(*pos.values())
df_source['x'] = x
df_source['y'] = y
node_source = ColumnDataSource(df_source)
node_source_bak = ColumnDataSource(df_source)

edge_source = ColumnDataSource(data=dict(
            start=[e[0] for e in G.edges(data=True)],
            end=[e[1] for e in G.edges(data=True)],
            weight=[e[2]['weight'] for e in G.edges(data=True)],
        ))
edge_source_bak = ColumnDataSource(data=dict(
            start=[e[0] for e in G.edges(data=True)],
            end=[e[1] for e in G.edges(data=True)],
            weight=[e[2]['weight'] for e in G.edges(data=True)],
        ))

edge_source1 = ColumnDataSource(data=dict(
            start=[e[0] for e in G.edges(data=True)],
            end=[e[1] for e in G.edges(data=True)],
            weight=[e[2]['weight'] for e in G.edges(data=True)],
        ))

# HACK: important! This dummy initialization make sure the 2 edge_sources are not pointing to same object in later javascript callback
edge_source.selected['2d'] = {'indices':[]}
edge_source1.selected['2d'] = {'indices':[]}

# common renderers
hover = HoverTool(
        tooltips=[
            ("id", "@id"),
            ("age", "@age"),
            ('win', "@win"),
            ('lose', "@lose"),
            ('score', "@score"),
            ("weighted_score", "@weighted_score"),
        ]
    )
labels = LabelSet(x='x', y='y', text='label', source=node_source)

# %%
def plot_graph(network, title, edge_src, x_range=None, y_range=None, label=True):
    TOOLS = "pan,wheel_zoom,box_select,lasso_select"
    if not x_range:
        x_range = Range1d(-1.2,1.2)
        y_range = Range1d(-1.2,1.2)
    fig = figure(tools=TOOLS, width=600, height=600,
                x_range=x_range, y_range=y_range)
    
    fig.title.text = title

    fig.add_tools(hover, TapTool(), BoxSelectTool(), LassoSelectTool())

    graph_renderer = from_networkx(network, nx.circular_layout, scale=1, center=(0,0))
    graph_renderer.layout_provider = StaticLayoutProvider(graph_layout=pos)

    graph_renderer.node_renderer.data_source = node_source
    graph_renderer.node_renderer.glyph = Circle(size='size', fill_color="fill_color")
    graph_renderer.node_renderer.selection_glyph = Circle(size='size', fill_color=Spectral4[2])
    graph_renderer.node_renderer.hover_glyph = Circle(size='size', fill_color=Spectral4[1])

    graph_renderer.edge_renderer.data_source = edge_src
    graph_renderer.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.8, line_width='weight')
    graph_renderer.edge_renderer.selection_glyph = MultiLine(line_color=Spectral4[2], line_width='weight')
    graph_renderer.edge_renderer.hover_glyph = MultiLine(line_color=Spectral4[1], line_width='weight')

    graph_renderer.selection_policy = NodesOnly() #NodesAndLinkedEdges()
    graph_renderer.inspection_policy = NodesAndLinkedEdges() #EdgesAndLinkedNodes()

    fig.renderers.append(graph_renderer)
    fig.renderers.append(labels)
    
    return fig

# %%
callback = CustomJS(args=dict(edge_source=edge_source, edge_source1=edge_source1, bak=edge_source_bak), code="""
        var range = cb_obj.value;
        var bakdata = bak.data;
        
        var weights = bakdata['weight'];
        for (i = 0; i < weights.length; i++) {
            if(weights[i] < range[0] || weights[i] > range[1]) {
                edge_source.data['start'][i] = 1;
                edge_source.data['end'][i] = 1;
                edge_source.data['weight'][i] = 0;
                
                edge_source1.data['start'][i] = 1;
                edge_source1.data['end'][i] = 1;
                edge_source1.data['weight'][i] = 0;
            }else{
                edge_source.data['start'][i] = bakdata['start'][i];
                edge_source.data['end'][i] = bakdata['end'][i];
                edge_source.data['weight'][i] = bakdata['weight'][i];
                
                edge_source1.data['start'][i] = bakdata['start'][i];
                edge_source1.data['end'][i] = bakdata['end'][i];
                edge_source1.data['weight'][i] = bakdata['weight'][i];
            }
        }   
        edge_source.change.emit();
        edge_source1.change.emit();
    """)

weight_max = df_edge['weight'].max()
range_slider = RangeSlider(start=1, end=weight_max, value=(1, weight_max), step=1, title="dominance range", callback=callback)

# %%
node_source.callback = CustomJS(args=dict(edge_source=edge_source, edge_source1=edge_source1), code="""
        var node_selected = cb_obj.selected['1d']['indices'];
        var edge_starts = {};
        var edge_ends = {};
        var edges = edge_source.data;

        for(i=0;i<node_selected.length;i++) {
            ix = node_selected[i];
            node_id = cb_obj.data['index'][ix]
            for(j=0;j<edges['start'].length;j++) {
                if(edges['start'][j] == node_id) {
                    edge_starts[j] = [0];
                }
                if(edges['end'][j] == node_id) {
                    edge_ends[j] = [0];
                }
            }
        }

        edge_source.selected['2d']['indices'] = edge_starts;
        edge_source1.selected['2d']['indices'] = edge_ends;

        cb_obj.change.emit();
        edge_source.change.emit();
        edge_source1.change.emit();

    """)

# %%
description = '''
<h3>Node of sheep</h3>
The <b>position</b> of sheep node are ordered counter-clockwise starting from 3 o'clock <br>
The <b>size</b> of node represents the total fights number of the sheep with others <br>
The <b>Color Hue</b> of the node shows whether the sheep has more wins(red) or more loss (blue), and the <b>saturation</b> indicates the node's score (wins-losses)<br>
<h3>Edge of fight</h3>
The <b>line_width</b> indicates the dominance weight of the fight<br>
'''
div = Div(text=description, width=1000)
dummy = Div(text='')

fig = plot_graph(G, 'Sheep fight wins', edge_source)
fig1 = plot_graph(G, 'Sheep fight loses', edge_source1, fig.x_range, fig.y_range)
p = gridplot([
    [div], 
    [range_slider],
    [fig, fig1]
])

output_file("interactive_graphs.html")
show(p)
# Out:
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='54d18ded-e625-4263-aa0e-6758acd75486', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='606b5385-26b3-426f-acef-34c7775fa23b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='81c28e5d-eff2-42b4-a29f-399ddf638006', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f99abc53-1f3b-481b-bc21-e9e9110ba8cb', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='23a32ba4-d3b1-45a6-96e8-c86ca1d44d3e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='719f019b-cb65-44f2-befe-abe19f2ce515', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b3083961-c04d-45dd-875a-804843e8b5de', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c90f1660-55bb-4171-a262-fd07ff19e27a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='041ea0b9-02b0-410e-851b-ce7ac6c3668d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='21687233-f455-4cfa-9ada-b556ddbc4cfa', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='7d078d0c-159e-4e49-a638-0a8098e38b47', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='eaced00d-c9b6-4fb3-9845-910dc1fd100a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='6a7eb17f-cc6d-40d9-87f9-d081a86a9a34', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='a7accd9a-707e-4322-98ca-12400f43d165', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f0b7dc1c-9e62-4f4d-9154-1ff0c2cb33ff', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='fcf98a01-b75a-4b85-8d89-1bed6aef341e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='87a1e71d-73bb-40af-a93a-4ce3d8b46cac', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='9739cc7b-2197-4cf4-a3d7-f5a91d65160e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='99dca16c-0545-45e1-88be-e7a92a6ea4db', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='cbb08e9a-cf9e-4cb0-ac24-fad8b88a8050', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1340c3ff-d0bc-45fc-b2ed-4ec120153c4d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='7032bb3c-f0f8-4617-9b28-67ad936e6fc3', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='dfa852ba-ced0-4b85-8249-0806b7620eee', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ecef0114-79e9-42f6-bf94-11d2ea91d228', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='4c494687-571f-4729-9bbc-a5edffa37b26', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c4b3f5b3-e53c-4204-b435-cd37910e3e55', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d04d90aa-5707-4cd6-a99d-cf5588ce84c1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d955676a-f71b-43b3-bf0b-e12ff7c425b8', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='001cef6c-2cb2-494e-88ac-f47c07674427', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='197193c9-c5c6-4852-80d7-b66b52596bc3', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='26f7d891-4b76-4cc1-9ccb-2cc069fa2a44', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d41b5303-cb1f-4797-a506-a3fab1c982cc', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='520cf41d-27da-4939-be55-950cfee8af9c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5686fa14-3e13-478c-a2ed-2ba1ba60bac5', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c7424418-0ed7-480d-af3e-08b63044216d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='edbbf2d8-5b43-470d-9b36-9756c8842132', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5620b8d0-6d74-4977-9e97-476082c73c42', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='9ff9d6b5-a54b-4223-8bf6-d89eba894e65', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b16ff4fd-347c-46ac-97ac-dfbb6b97281f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e212814c-f3fe-4fc3-ae40-d30fc2067ec2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5ccb6e74-160d-41ff-8a1c-ca7cdaa2b7d2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bcf41a01-4609-4261-b21d-5c97e48e7f3b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c04e4bb4-ee78-48ac-9a4c-50e872da5452', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d232ad7d-865e-4d4a-adf6-eb85afda1fe5', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='07519f5e-328f-4e1f-ab75-8df80bd7ecf9', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1941fccf-d2bc-4c08-bcb5-514a637fb353', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8983eb63-fdff-434b-ac53-31cf06ff5fd4', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d6636400-34e1-4b53-9257-a315b7b85ab5', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1c8e7479-12cb-4d1f-b696-78e931d0aa8c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2ce7d46c-9ee9-438f-b3d6-14d483eb7d3f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='30fb1d74-078a-4ec5-8219-d7ee9bb6c91b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='6b861ca7-c604-4957-9bf5-4cf61a9969cc', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='29986cc8-25c1-4629-99b6-179c446ead3a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='5b150d79-5c57-4b7f-91c5-adee5875731b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='665d57b3-e049-449d-ae85-b4804c57f288', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ea161cbc-f3dc-4f2f-9a7c-58d75b99cd37', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1dd6783f-47a5-42e7-ad3a-8dd1f3088fa1', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='2606f6f3-7501-45b0-8ac0-51879990c470', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8057d1e0-af4a-4999-9fb5-8e6bd4ce194a', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='8acbb664-8a72-4119-95f3-6eeccaefae1a', ...)
# c:\users\wenyan\anaconda3\envs\dse241\lib\site-packages\bokeh\core\json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
